# %%
import IPython
b=0
class Library:
    def __init__(shelf, listOfBooks):
        shelf.books = listOfBooks

    def displayAvailableBooks(shelf):
        print("Books present in this library are: ")
        for book in shelf.books: 
            print(" *" + book)
    
    def borrowBook(shelf, bookName):
        if bookName in shelf.books:
            a=input('Enter your name: ')
            b=input('Enter you gmail ID: ')
            while '@gmail.com'in b:
                break
            while '@gmail.com'not in b:
                print('WRONG ID! Enter the valid ID')
                IPython.display.display(IPython.display.Audio(r"C:\Users\ayush\Music\1.mp3", autoplay=True))
                print()
                b=input('Enter you gmail ID: ')
                continue
            print(f"You have been issued {bookName}. Please keep it safe and return it within 30 days")
            shelf.books.remove(bookName)
            return True
        else:
            print("Sorry, This book is either not available or has already been issued to someone else. Please wait until the book is available")
            return False

    def returnBook(shelf, bookName):
        a=input('Enter your name: ')
        b=input('Enter you gmail ID: ')
        while '@gmail.com'in b:
            break
        while '@gmail.com'not in b:
            print('WRONG ID! Enter the valid ID')
            IPython.display.display(IPython.display.Audio(r"C:\Users\ayush\Music\1.mp3", autoplay=True))
            print()
            b=input('Enter you gmail ID: ')
            continue
        print("Thanks for returning this book! Hope you enjoyed reading it. Have a great day ahead!")
        shelf.books.append(bookName)
        
    
def return_menu():
    print()
    print('''Please choose an option:
              1. Return to main menu
              2. Exit library''')
    global b
    b=int(input("Enter a choice: "))
    if b == 1:
        pass
    while b == 2:
        print("Thanks for choosing Your Library. Have a great day ahead!")
        IPython.display.display(IPython.display.Audio(r"C:\Users\ayush\Music\Exit.mp3", autoplay=True))
        break
    if b>2:
        IPython.display.display(IPython.display.Audio(r"C:\Users\ayush\Music\1.mp3", autoplay=True))
        print('''Invalid Choice!
        choose the correct option''')
        
        
            

class Student: 
    def requestBook(shelf):
        shelf.book = input("Enter the name of the book you want to borrow: ")
        return shelf.book

    def returnBook(shelf):
        shelf.book = input("Enter the name of the book you want to return: ")
        return shelf.book
         

if True:
    YourLibrary = Library(["Algorithms", "Django", "Clrs", "Python Notes","CASA","python","basic electronics"])
    student = Student()
    # YourLibrary.displayAvailableBooks()
    while(True):
        welcomeMsg = '''\n ====== WELCOME TO YOUR LIBRARY ======
        Please choose an option:
        1. List all the books
        2. Request a book
        3. Return a book
        '''
        IPython.display.display(IPython.display.Audio(r"C:\Users\ayush\Music\Welcome.mp3", autoplay=True))
        
        
        while b!=2:
            print(welcomeMsg)
            a = int(input("Enter a choice: "))
            if a == 1:
                YourLibrary.displayAvailableBooks()
                return_menu()

            elif a == 2:
                YourLibrary.borrowBook(student.requestBook())
                return_menu()

            elif a == 3:
                YourLibrary.returnBook(student.returnBook())
                return_menu()

            else:
                IPython.display.display(IPython.display.Audio(r"C:\Users\ayush\Music\1.mp3", autoplay=True))
                print("Invalid Choice!")
        else:
            break
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#  ====== WELCOME TO YOUR LIBRARY ======
#         Please choose an option:
#         1. List all the books
#         2. Request a book
#         3. Return a book
#
# Enter a choice: 1
# Books present in this library are:
#  *Algorithms
#  *Django
#  *Clrs
#  *Python Notes
#  *CASA
#  *python
#  *basic electronics
#
# Please choose an option:
#               1. Return to main menu
#               2. Exit library
# Enter a choice: 1
#
#  ====== WELCOME TO YOUR LIBRARY ======
#         Please choose an option:
#         1. List all the books
#         2. Request a book
#         3. Return a book
#
# Enter a choice: 2
# Enter the name of the book you want to borrow: CASA
# Enter your name: a
# Enter you gmail ID: a
# WRONG ID! Enter the valid ID
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Enter you gmail ID: a@gmail.com
# You have been issued CASA. Please keep it safe and return it within 30 days
#
# Please choose an option:
#               1. Return to main menu
#               2. Exit library
# Enter a choice: 1
#
#  ====== WELCOME TO YOUR LIBRARY ======
#         Please choose an option:
#         1. List all the books
#         2. Request a book
#         3. Return a book
#
# Enter a choice: 3
# Enter the name of the book you want to return: CASA
# Enter your name: a
# Enter you gmail ID: a
# WRONG ID! Enter the valid ID
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Enter you gmail ID: a@gmail.com
# Thanks for returning this book! Hope you enjoyed reading it. Have a great day ahead!
#
# Please choose an option:
#               1. Return to main menu
#               2. Exit library
# Enter a choice: 3
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Invalid Choice!
#         choose the correct option
#
#  ====== WELCOME TO YOUR LIBRARY ======
#         Please choose an option:
#         1. List all the books
#         2. Request a book
#         3. Return a book
#
# Enter a choice: 4
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Invalid Choice!
#
#  ====== WELCOME TO YOUR LIBRARY ======
#         Please choose an option:
#         1. List all the books
#         2. Request a book
#         3. Return a book
#
# Enter a choice: 1
# Books present in this library are:
#  *Algorithms
#  *Django
#  *Clrs
#  *Python Notes
#  *python
#  *basic electronics
#  *CASA
#
# Please choose an option:
#               1. Return to main menu
#               2. Exit library
# Enter a choice: 2
# Thanks for choosing Your Library. Have a great day ahead!
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
